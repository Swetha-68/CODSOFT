# %% [markdown]
# <a href="https://colab.research.google.com/github/Swetha-68/CODSOFT/blob/main/TASK_1_COD_SOFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/Titanic-Dataset.csv')
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
values=df.drop('Survived',axis='columns')
to_predict=df.Survived
d=pd.get_dummies(values.Sex)
values=pd.concat([values,d],axis='columns')
values.drop('Sex',axis='columns',inplace=True)
values.head()
# Out:
#    Pclass   Age     Fare  female  male
# 0       3  22.0   7.2500       0     1
# 1       1  38.0  71.2833       1     0
# 2       3  26.0   7.9250       1     0
# 3       1  35.0  53.1000       1     0
# 4       3  35.0   8.0500       0     1

# %%
to_predict.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
values.columns[values.isna().any()]
# Out:
# Index(['Age'], dtype='object')

# %%
values.Age=values.Age.fillna(values.Age.mean())
values.columns[values.isna().any()]
# Out:
# Index([], dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
a,b,c,d=train_test_split(values,to_predict,test_size=0.2)
m=GaussianNB()
m.fit(a,c)
# Out:
# GaussianNB()

# %%
m.score(b,d)
# Out:
# 0.776536312849162

# %%
d[10:15]
# Out:
# 152    0
# 516    1
# 191    0
# 306    1
# 228    0
# Name: Survived, dtype: int64

# %%
m.predict(b[10:15])
# Out:
# array([0, 1, 0, 1, 0])
